# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("leosource.jpg")
plt.imshow(img)
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
template = cv2.imread("Leopng.jpg", cv2.IMREAD_GRAYSCALE)
w, h = template.shape[::-1]
result = cv2.matchTemplate(gray_img, template, cv2.TM_CCOEFF_NORMED)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-2-89a15d869cf7> in <module>
#       4 template = cv2.imread("Leopng.jpg", cv2.IMREAD_GRAYSCALE)
#       5 w, h = template.shape[::-1]
# ----> 6 result = cv2.matchTemplate(gray_img, template, cv2.TM_CCOEFF_NORMED)
#
# error: OpenCV(3.4.2) C:\projects\opencv-python\opencv\modules\imgproc\src\templmatch.cpp:1107: error: (-215:Assertion failed) _img.size().height <= _templ.size().height && _img.size().width <= _templ.size().width in function 'cv::matchTemplate'

# %%
print(img)
print("img shape:", img.shape)
print(template)
print("template shape:", template.shape)
print(result)
print("result shape:", result.shape)
print("w:", w)
print("h:", h)

# %%
loc = np.where(result >= 0.9)
for pt in zip(*loc[::-1]):
    cv2.rectangle(img, pt, (pt[0]+ w, pt[1]+ h), (0, 255, 0), 3 )

# %%
cv2.imshow("img", img)
cv2.waitKey(0)
cv2.destroyAllWindows()
